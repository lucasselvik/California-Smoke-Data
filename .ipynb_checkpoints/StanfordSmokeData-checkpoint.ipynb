# %%
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.animation import FuncAnimation

# %% [markdown]
# Import data:

# %%
smoke_csv = "./10km_grid/smokePM2pt5_predictions_daily_10km_20060101-20201231.csv"
smoke = pd.read_csv(smoke_csv)
smoke['date'] = pd.to_datetime(smoke['date'], format="%Y%m%d")
smoke.iloc[:5,:]
# Out:
#    grid_id_10km       date  smokePM_pred
# 0         56334 2006-01-01      2.709746
# 1         56335 2006-01-01      3.067258
# 2         56336 2006-01-01      2.482192
# 3         56337 2006-01-01      3.093114
# 4         56338 2006-01-01      3.667933

# %% [markdown]
# Filter the date:

# %%
smoke_2020 = smoke[(smoke['date'] >= "2020-08-01") & (smoke['date'] <= "2020-09-30")]
smoke_2020.iloc[:5,:]
# Out:
#           grid_id_10km       date  smokePM_pred
# 46997264         38438 2020-08-01      2.459065
# 46997265         38439 2020-08-01      2.374383
# 46997266         38440 2020-08-01      2.738663
# 46997267         38441 2020-08-01      2.587327
# 46997268         38442 2020-08-01      4.757607

# %% [markdown]
# ## Select a specific date:
# _this can be changed_

# %%
day = pd.to_datetime("2020-08-31")
smoke_day = smoke_2020[smoke_2020['date'] == day]
smoke_day = smoke_day[smoke_day['smokePM_pred'] > 0]
smoke_day
# Out:
#           grid_id_10km       date  smokePM_pred
# 48308053         43128 2020-08-31      0.644423
# 48308054         43129 2020-08-31      0.923814
# 48308055         43643 2020-08-31      0.584444
# 48308056         43644 2020-08-31      0.774008
# 48308057         43645 2020-08-31      0.939985
# ...                ...        ...           ...
# 48348364        209739 2020-08-31      0.554067
# 48348365        209740 2020-08-31      0.577754
# 48348366        209741 2020-08-31      0.593932
# 48348367        209742 2020-08-31      0.560694
# 48348368        210256 2020-08-31      0.509555
#
# [40272 rows x 3 columns]

# %% [markdown]
# Load the grid shape file:

# %%
grid_shp = "./10km_grid/10km_grid_wgs84/10km_grid_wgs84.shp"
grid = gpd.read_file(grid_shp)

# merge predictions with the grid
grid = grid.merge(smoke_day, left_on='ID', right_on='grid_id_10km')

# fill Na with 0
grid['smokePM_pred'] = grid['smokePM_pred'].fillna(0)

# convert to a GeoDataFrame
grid = gpd.GeoDataFrame(grid, geometry='geometry', crs=grid.crs)

grid.iloc[:5,:]
# Out:
#       ID    COORDX     COORDY  \
# 0  43128 -640000.0  3580000.0
# 1  43129 -630000.0  3580000.0
# 2  43643 -640000.0  3590000.0
# 3  43644 -630000.0  3590000.0
# 4  43645 -620000.0  3590000.0
#
#                                             geometry  grid_id_10km       date  \
# 0  POLYGON ((-80.95602 31.83343, -80.9445 31.7451...         43128 2020-08-31
# 1  POLYGON ((-80.85262 31.84325, -80.84119 31.754...         43129 2020-08-31
# 2  POLYGON ((-80.96759 31.92169, -80.95602 31.833...         43643 2020-08-31
# 3  POLYGON ((-80.86409 31.93154, -80.85262 31.843...         43644 2020-08-31
# 4  POLYGON ((-80.76055 31.94131, -80.74916 31.852...         43645 2020-08-31
#
#    smokePM_pred
# 0      0.644423
# 1      0.923814
# 2      0.584444
# 3      0.774008
# 4      0.939985

# %% [markdown]
# Filter to California:

# %%
states = gpd.read_file("./tl_2025_us_state/tl_2025_us_state.shp")
california = states[states["NAME"] == "California"]
california = california.to_crs(grid.crs)
grid_ca = gpd.sjoin(grid, california, how='inner', predicate='intersects')

# %% [markdown]
# Plot:

# %%
fig, ax = plt.subplots(figsize=(10,10))
grid_ca.plot(
    column='smokePM_pred',
    cmap='magma',
    legend=True,
    ax=ax,
    legend_kwds={'label': "PM2.5 (µg/m³)"}
)

california.boundary.plot(ax=ax, color='black', linewidth=1)

plt.title(f"Smoke PM2.5 in California – {day.date()}", fontsize=16)
plt.axis('off')
plt.show()
